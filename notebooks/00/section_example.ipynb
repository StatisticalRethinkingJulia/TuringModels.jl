# %%
using TuringModels

@model model() = begin
    a ~ Normal(-10,.1)
    b ~ Normal(-8,.1)
    c ~ Normal(-6,.1)
    d ~ Normal(-4,.1)
    return nothing
end

Nsamples = 2000
Nadapt = 1000
draws = Nadapt+1 : Nsamples
δ = .85
sampler = NUTS(Nsamples, Nadapt, δ)

sampler = Turing.NUTS(2000, 1000, 0.65)
chn = sample(model(), sampler)

chn1 = set_section(chn, Dict(
  :parameters => ["a", "c"],
  :pooled => ["b", "d"],
  :internals => ["elapsed", "epsilon", "eval_num", "lf_eps", "lf_num", "lp"])
)

describe(chn1)
describe(chn1, section=:pooled)
describe(chn1, section=:internals)
# Out:
# ┌ Info: [Turing] looking for good initial eps...
# └ @ Turing.Inference /Users/rob/.julia/packages/Turing/yF1Mq/src/inference/support/hmc_core.jl:245
# ┌ Info: [Turing] found initial ϵ: 0.2002197265625
# └ @ Turing.Inference /Users/rob/.julia/packages/Turing/yF1Mq/src/inference/support/hmc_core.jl:237
# ┌ Info:  Adapted ϵ = 0.11348655340526526, std = [1.0, 1.0, 1.0, 1.0]; 1000 iterations is used for adaption.
# └ @ Turing.Inference /Users/rob/.julia/packages/Turing/yF1Mq/src/inference/adapt/adapt.jl:90
# [NUTS] Finished with
#   Running time        = 1.3832216270000006;
#   #lf / sample        = 0.0;
#   #evals / sample     = 10.6475;
#   pre-cond. metric    = [1.0, 1.0, 1.0, 1.0].
# Log evidence      = 0.0
# Iterations        = 1:2000
# Thinning interval = 1
# Chains            = 1
# Samples per chain = 2000
# parameters        = a, c
#
# Empirical Posterior Estimates
# ────────────────────────────────────────────
# parameters
#     Mean     SD   Naive SE  MCSE     ESS
# a -10.0228 0.5140   0.0115 0.0216 566.1011
# c  -6.0109 0.2734   0.0061 0.0109 625.3993
#
# Quantiles
# ────────────────────────────────────────────
# parameters
#     2.5%     25.0%    50.0%   75.0%   97.5%
# a -22.3242 -10.0688 -10.0018 -9.9350 -5.5043
# c -12.2686  -6.0655  -6.0026 -5.9339 -3.7668
#
# Log evidence      = 0.0
# Iterations        = 1:2000
# Thinning interval = 1
# Chains            = 1
# Samples per chain = 2000
# pooled            = b, d
#
# Empirical Posterior Estimates
# ──────────────────────────────────────────
# pooled
#     Mean    SD   Naive SE  MCSE     ESS
# b -8.0152 0.4093   0.0092 0.0168 595.1005
# d -4.0085 0.2298   0.0051 0.0092 630.2290
#
# Quantiles
# ──────────────────────────────────────────
# pooled
#     2.5%    25.0%   50.0%   75.0%   97.5%
# b -17.7191 -8.0673 -7.9981 -7.9318 -4.5114
# d  -9.0613 -4.0663 -4.0020 -3.9352 -2.1067
#
# Log evidence      = 0.0
# Iterations        = 1:2000
# Thinning interval = 1
# Chains            = 1
# Samples per chain = 2000
# internals         = elapsed, epsilon, eval_num, lf_eps, lf_num, lp
#
# Empirical Posterior Estimates
# ───────────────────────────────────────────────────────
# internals
#            Mean      SD    Naive SE   MCSE     ESS
#  elapsed   0.0007   0.0054   0.0001  0.0002 901.9173
#  epsilon   0.1255   0.0805   0.0018  0.0034 548.6847
# eval_num  10.6475   6.4140   0.1434  0.3234 393.2450
#   lf_eps   0.1255   0.0805   0.0018  0.0034 548.6847
#   lf_num   0.0000   0.0000   0.0000  0.0000      NaN
#       lp -22.4622 605.8335  13.5468 26.0705 540.0164
#
# Quantiles
# ───────────────────────────────────────────────────────
# internals
#               2.5%       25.0%   50.0%   75.0%   97.5%
#  elapsed 1.0000000×10⁻⁴  0.0004  0.0004  0.0004  0.1750
#  epsilon 2.3300000×10⁻²  0.1135  0.1135  0.1206  1.7302
# eval_num  4.0000000×10⁰ 10.0000 10.0000 10.0000 94.0000
#   lf_eps 2.3300000×10⁻²  0.1135  0.1135  0.1206  1.7302
#   lf_num              0  0.0000  0.0000  0.0000  0.0000
#       lp -1.5557483×10⁴  2.8845  3.8757  4.6037  5.4967

# %% [markdown]
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
